# %%
import pandas as pd

fichier_dvf = "pharmacies_point.csv"

df = pd.read_csv(fichier_dvf, sep=";", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 5
#       1 import pandas as pd
#       3 fichier_dvf = "pharmacies_point.csv"
# ----> 5 df = pd.read_csv(fichier_dvf, sep=";", encoding="utf-8")
#
# ...

# %%
fichier_dvf = "pharmacies_point.csv"

df = pd.read_csv(fichier_dvf)


df = pd.read_csv(fichier_dvf)
szns
# Out:
# /tmp/ipykernel_56354/218740887.py:3: DtypeWarning: Columns (4,11,16,32,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fichier_dvf)
#                                FID      osm_id   amenity  \
# 0      pharmacies_point.4534591198  4534591198  pharmacy
# 1      pharmacies_point.3770631311  3770631311  pharmacy
# 2       pharmacies_point.172156934   172156934  pharmacy
# 3      pharmacies_point.3918927589  3918927589  pharmacy
# 4      pharmacies_point.2749148434  2749148434  pharmacy
# ...                            ...         ...       ...
# 19122  pharmacies_point.1008156074  1008156074  pharmacy
# 19123  pharmacies_point.3712079795  3712079795  pharmacy
# 19124  pharmacies_point.1933342224  1933342224  pharmacy
# 19125  pharmacies_point.3485646116  3485646116  pharmacy
# 19126  pharmacies_point.1152714441  1152714441  pharmacy
#
#                               name short_name official_name alt_name  \
# ...
